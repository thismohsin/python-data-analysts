# %% [markdown]
# ## Heatmap
# https://plot.ly/python/heatmaps/
#
# A heatmap is a graphical representation of data where the individual values contained in a matrix are represented as colors.

# %% [markdown]
# ### Importing packages

# %%
import plotly.graph_objs as go
import plotly.offline as offline

offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ##### plotting simple heatmap with two rows and two columns

# %%
trace = go.Heatmap(z = [[8, 64],
                        [3, 37]])

# %%
data = [trace]

offline.iplot(data)
# Out:
# <div>
#
#
#             <div id="0de7a2e4-b3d8-4a4e-83e0-10ebe787dcae" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0de7a2e4-b3d8-4a4e-83e0-10ebe787dcae")) {
#                     Plotly.newPlot(
#                         '0de7a2e4-b3d8-4a4e-83e0-10ebe787dcae',
#                         [{"type": "heatmap", "uid": "8cbcb675-236f-4ede-b2c5-a3d6834122dc", "z": [[8, 64], [3, 37]]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('0de7a2e4-b3d8-4a4e-83e0-10ebe787dcae');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ##### ploting heatmap with three rows and three columns

# %%
trace = go.Heatmap(z = [[8, 64, 98],
                        [3, 37, 18],
                        [55, 23, 41]])

# %%
data = [trace]

offline.iplot(data)
# Out:
# <div>
#
#
#             <div id="da9b2ae3-d2b9-4c58-b52f-2e2c8b722c77" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("da9b2ae3-d2b9-4c58-b52f-2e2c8b722c77")) {
#                     Plotly.newPlot(
#                         'da9b2ae3-d2b9-4c58-b52f-2e2c8b722c77',
#                         [{"type": "heatmap", "uid": "f27f2c40-b07c-4a07-9b48-9294b82797f8", "z": [[8, 64, 98], [3, 37, 18], [55, 23, 41]]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('da9b2ae3-d2b9-4c58-b52f-2e2c8b722c77');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ##### Loading california housing dataset

# %%
import pandas as pd

housing_data = pd.read_csv('datasets/housing.csv')

housing_data.sample(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3812     -118.48     34.21                25.0       2879.0           723.0
# 19283    -122.73     38.40                30.0       3689.0           746.0
# 10929    -117.90     33.74                19.0       1566.0           379.0
# 14117    -117.11     32.73                34.0       1096.0           221.0
# 8338     -118.31     33.93                42.0       1173.0           201.0
# 2881     -118.99     35.38                26.0       1317.0           374.0
# 15942    -122.42     37.72                37.0       2638.0           546.0
# 11401    -117.93     33.72                17.0       4461.0           585.0
# 777      -122.10     37.65                31.0       1797.0           327.0
# 13308    -117.61     34.08                20.0       3550.0           736.0
#
#        population  households  median_income  median_house_value  \
# 3812       2077.0       649.0         3.3864            197400.0
# 19283      2250.0       697.0         2.9750            157300.0
# 10929      1032.0       330.0         2.2105            180400.0
# 14117       574.0       223.0         3.8355            126700.0
# 8338        602.0       186.0         5.5787            142000.0
# 2881       1025.0       304.0         1.4024             51000.0
# 15942      1789.0       521.0         4.0071            244700.0
# 11401      2095.0       580.0         7.6709            319500.0
# 777         796.0       319.0         4.4427            204500.0
# 13308      2229.0       681.0         3.0199            128800.0
#
#       ocean_proximity
# 3812        <1H OCEAN
# 19283       <1H OCEAN
# 10929       <1H OCEAN
# 14117      NEAR OCEAN
# 8338        <1H OCEAN
# 2881           INLAND
# 15942        NEAR BAY
# 11401       <1H OCEAN
# 777          NEAR BAY
# 13308          INLAND

# %%
housing_data.shape
# Out:
# (20640, 10)

# %%
housing_data = housing_data.sample(frac=0.1).reset_index(drop=True)

housing_data.shape
# Out:
# (2064, 10)

# %%
median = housing_data['median_house_value'].median()

median
# Out:
# 179200.0

# %% [markdown]
# ##### adding one column 'above_median' in the dataset for median_house_value is greater or lesser than median value of the whole column values

# %%
housing_data['above_median'] = (housing_data['median_house_value'] - median) > 0

housing_data.sample(5)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 418     -118.30     34.17                30.0         48.0            14.0
# 1853    -119.47     35.14                19.0       4190.0           690.0
# 465     -118.13     34.19                43.0       1621.0           365.0
# 1010    -115.72     32.75                16.0        348.0            99.0
# 1776    -122.01     37.34                31.0       3080.0           526.0
#
#       population  households  median_income  median_house_value  \
# 418         74.0        16.0         5.0056            162500.0
# 1853      1973.0       702.0         3.9929             88300.0
# 465       1015.0       329.0         2.9200            242200.0
# 1010       123.0        54.0         2.0938             87500.0
# 1776      1493.0       582.0         6.3052            344200.0
#
#      ocean_proximity  above_median
# 418        <1H OCEAN         False
# 1853          INLAND         False
# 465           INLAND          True
# 1010          INLAND         False
# 1776       <1H OCEAN          True

# %% [markdown]
# ##### plotting heatmap as ocean_proximity on x axis and above_median on y axis

# %%
trace = go.Heatmap(z = housing_data['median_house_value'],
                   
                   x = housing_data['ocean_proximity'],
                   
                   y = housing_data['above_median'],
                   
                   colorscale = 'Jet',
                   
                   reversescale = True
                  )

# %%
data = [trace]

offline.iplot(data)
# Out:
# <div>
#
#
#             <div id="fef72b70-c797-4f72-80d5-f0621c843952" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fef72b70-c797-4f72-80d5-f0621c843952")) {
#                     Plotly.newPlot(
#                         'fef72b70-c797-4f72-80d5-f0621c843952',
#                         [{"colorscale": "Jet", "reversescale": true, "type": "heatmap", "uid": "1fc8fe78-4c72-41e8-ae26-fd7b552cbe77", "x": ["<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "INLAND", "NEAR BAY", "<1H OCEAN", "INLAND", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "NEAR BAY", "NEAR OCEAN", "INLAND", "INLAND", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR BAY", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "NEAR OCEAN", "INLAND", "INLAND", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "NEAR OCEAN", "NEAR OCEAN", "INLAND", "NEAR BAY", "<1H OCEAN", "NEAR OCEAN", "INLAND", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "NEAR BAY", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "NEAR BAY", "INLAND", "<1H OCEAN", "NEAR BAY", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "NEAR OCEAN", "NEAR BAY", "<1H OCEAN", "INLAND", "NEAR BAY", "INLAND", "NEAR BAY", "<1H OCEAN", "INLAND", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR OCEAN", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "INLAND", "NEAR OCEAN", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "INLAND", "INLAND", "NEAR OCEAN", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "NEAR BAY", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR BAY", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR OCEAN", "INLAND", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "INLAND", "<1H OCEAN", "INLAND", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "NEAR BAY", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR BAY", "<1H OCEAN", "NEAR BAY", "INLAND", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR BAY", "<1H OCEAN", "INLAND", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR BAY", "NEAR OCEAN", "NEAR BAY", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR OCEAN", "INLAND", "NEAR BAY", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "NEAR BAY", "INLAND", "NEAR OCEAN", "INLAND", "NEAR BAY", "NEAR OCEAN", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "NEAR OCEAN", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "INLAND", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "INLAND", "INLAND", "<1H OCEAN", "INLAND", "NEAR OCEAN", "INLAND", "<1H OCEAN", "NEAR OCEAN", "NEAR BAY", "INLAND", "NEAR OCEAN", "<1H  ...
