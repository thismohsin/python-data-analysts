# %% [markdown]
# ## Bubble Chart
# https://plot.ly/python/bubble-charts/
#
# A bubble chart is a variation of a scatter chart in which the data points are replaced with bubbles, and additional dimension of the data is represented in the size of the bubbles and color.

# %% [markdown]
# ### Importing packages

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading https://files.pythonhosted.org/packages/3c/7e/bafb51ecd654a16f593beceb8e4e4069e33fccf47a3d071e0ef9b821a694/plotly-3.9.0-py2.py3-none-any.whl (41.2MB)
#      |████████████████████████████████| 41.2MB 365kB/s  eta 0:00:01     |████████████████████            | 25.7MB 41.0MB/s eta 0:00:01
# Collecting retrying>=1.3.3 (from plotly)
#   Downloading https://files.pythonhosted.org/packages/44/ef/beae4b4ef80902f22e3af073397f079c96969c69b2c7d52a57ea9ae61c9d/retrying-1.3.3.tar.gz
# Requirement already satisfied: six in /anaconda3/lib/python3.6/site-packages (from plotly) (1.11.0)
# Requirement already satisfied: requests in /anaconda3/lib/python3.6/site-packages (from plotly) (2.18.4)
# Requirement already satisfied: pytz in /anaconda3/lib/python3.6/site-packages (from plotly) (2017.3)
# Requirement already satisfied: decorator>=4.0.6 in /anaconda3/lib/python3.6/site-packages (from plotly) (4.2.1)
# Requirement already satisfied: nbformat>=4.2 in /anaconda3/lib/python3.6/site-packages (from plotly) (4.4.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.6/site-packages (from requests->plotly) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /anaconda3/lib/python3.6/site-packages (from requests->plotly) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /anaconda3/lib/python3.6/site-packages (from requests->plotly) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.6/site-packages (from requests->plotly) (2018.4.16)
# Requirement already satisfied: ipython_genutils in /anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in /anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly) (4.3.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly) (2.6.0)
# Requirement already satisfied: jupyter_core in /anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly) (4.4.0)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py) ... done
#   Stored in directory: /Users/jananiravi/Library/Caches/pip/wheels/d7/a9/33/acc7b709e2a35caa7d4cae442f6fe6fbf2c43f80823d46460c
# Successfully built retrying
# Installing collected packages: retrying, plotly
# Successfully installed plotly-3.9.0 retrying-1.3.3
# WARNING: You are using pip version 19.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import plotly
import plotly.graph_objs as go
import plotly.offline as offline

offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
plotly.__version__
# Out:
# '3.9.0'

# %% [markdown]
# ##### Regular 2D scatter plot

# %%
trace = go.Scatter (x = [15, 18, 21, 25],
                    
                    y = [100, 400, 300, 200],
                    
                    mode = 'markers')

data = [trace]

offline.iplot(data)
# Out:
# <div>
#
#
#             <div id="22fe0d62-ca8f-4a26-bb33-73db272d63c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("22fe0d62-ca8f-4a26-bb33-73db272d63c1")) {
#                     Plotly.newPlot(
#                         '22fe0d62-ca8f-4a26-bb33-73db272d63c1',
#                         [{"mode": "markers", "type": "scatter", "uid": "68caa0e5-7157-43aa-83fb-54f6ed9dd30f", "x": [15, 18, 21, 25], "y": [100, 400, 300, 200]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('22fe0d62-ca8f-4a26-bb33-73db272d63c1');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Representing a 3rd dimension of data in the same scatter plot

# %%
z = [25, 100, 75, 50]

# %%
trace = go.Scatter (x = [15, 18, 21, 25],
                    
                    y = [100, 400, 300, 200],
                    
                    mode = 'markers',
                    
                    marker = dict(size = z)
                   )

data = [trace]

offline.iplot(data)
# Out:
# <div>
#
#
#             <div id="9865ed4e-1622-4872-b5e5-825cb943d6c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9865ed4e-1622-4872-b5e5-825cb943d6c3")) {
#                     Plotly.newPlot(
#                         '9865ed4e-1622-4872-b5e5-825cb943d6c3',
#                         [{"marker": {"size": [25, 100, 75, 50]}, "mode": "markers", "type": "scatter", "uid": "63514c44-668d-496c-953d-b3d8d31a0100", "x": [15, 18, 21, 25], "y": [100, 400, 300, 200]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('9865ed4e-1622-4872-b5e5-825cb943d6c3');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Representing a 4th dimension in the same plot and use color to represent it

# %%
i = [5, 6, 8, 4]

# %%
trace = go.Scatter (x = [15, 18, 21, 25],
                    
                    y = [100, 400, 300, 200],
                    
                    mode = 'markers',
                    
                    marker = dict(size = z,
                                  color = i,
                                  colorscale = 'Portland',
                                  showscale = True)
                   )

# %%
data = [trace]
offline.iplot(data)
# Out:
# <div>
#
#
#             <div id="ac33b014-60a7-420f-988e-aab60af5413a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ac33b014-60a7-420f-988e-aab60af5413a")) {
#                     Plotly.newPlot(
#                         'ac33b014-60a7-420f-988e-aab60af5413a',
#                         [{"marker": {"color": [5, 6, 8, 4], "colorscale": "Portland", "showscale": true, "size": [25, 100, 75, 50]}, "mode": "markers", "type": "scatter", "uid": "058eae7f-bc00-4738-a865-85f4580ddcdd", "x": [15, 18, 21, 25], "y": [100, 400, 300, 200]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('ac33b014-60a7-420f-988e-aab60af5413a');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# #### Loading the dataset
# Here we are loading the csv format data that we saved in the previous demo

# %%
housing_data = pd.read_csv('datasets/housing.csv')

housing_data.sample(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9140     -118.27     34.46                10.0       2184.0           405.0
# 2264     -119.81     36.78                36.0       1650.0           313.0
# 13143    -121.54     38.29                47.0       1396.0           254.0
# 5643     -118.31     33.74                22.0       5042.0           974.0
# 17022    -122.31     37.52                24.0       2328.0           335.0
# 127      -122.21     37.84                44.0       3424.0           597.0
# 12327    -116.51     33.96                16.0       4913.0          1395.0
# 5734     -118.23     34.16                31.0       3105.0           582.0
# 5907     -118.44     34.29                35.0       2606.0           447.0
# 383      -122.16     37.74                47.0        824.0           223.0
#
#        population  households  median_income  median_house_value  \
# 9140       1119.0       370.0         4.7437            294000.0
# 2264        660.0       298.0         3.0000             79700.0
# 13143       630.0       218.0         2.8616             92500.0
# 5643       2260.0       935.0         4.3472            351200.0
# 17022       969.0       354.0         7.7364            435800.0
# 127        1358.0       597.0         6.0194            292300.0
# 12327      2518.0      1132.0         1.4665             61100.0
# 5734       1359.0       547.0         5.1718            429100.0
# 5907       1555.0       404.0         4.6864            193800.0
# 383         533.0       166.0         2.6250             98200.0
#
#       ocean_proximity
# 9140           INLAND
# 2264           INLAND
# 13143          INLAND
# 5643       NEAR OCEAN
# 17022      NEAR OCEAN
# 127          NEAR BAY
# 12327          INLAND
# 5734        <1H OCEAN
# 5907        <1H OCEAN
# 383          NEAR BAY

# %%
housing_data.shape
# Out:
# (20640, 10)

# %% [markdown]
# ##### dataset is very big so we are taking only 1% length of the dataset

# %%
housing_data = housing_data.sample(frac=0.07).reset_index(drop=True)

housing_data.shape
# Out:
# (1445, 10)

# %% [markdown]
# ##### showing unique values of ocean_proximity

# %%
housing_data['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', 'NEAR OCEAN', '<1H OCEAN', 'INLAND'], dtype=object)

# %% [markdown]
# ##### plotting the bubble chart where the size of bubble is related to households and color is related to housing_median_age

# %%
trace = go.Scatter(x = housing_data['median_income'],
                   y = housing_data['median_house_value'],
                   
                   mode = 'markers',
                   
                   marker = dict(
                                 size = housing_data['total_rooms'],
                                 sizeref = 500,
                                
                                 color = housing_data['housing_median_age'],
                                 colorscale = 'Jet',
                                 showscale = True))

# %%
data = [trace]

layout = go.Layout(height = 600,
                   width = 900,
                  
                   title = 'Housing Data',
                   hovermode = 'closest')

# %%
fig = go.Figure(data = data,
                layout = layout)

offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="0a61130d-ba5a-4052-a9c4-7ec3b8b71f00" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("