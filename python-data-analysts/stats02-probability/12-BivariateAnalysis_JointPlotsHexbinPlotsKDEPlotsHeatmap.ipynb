# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Loading dataset

# %%
tips_data = pd.read_csv('dataset/tips.csv')

tips_data.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
plt.figure(figsize=(10, 8))

sns.scatterplot(x='total_bill', y='tip', data=tips_data)

plt.xlabel('Total Bill')
plt.ylabel('Tip')

plt.show()

# %%
plt.figure(figsize=(10, 8))

sns.scatterplot(x='total_bill', y='tip', hue='smoker', data=tips_data)

plt.xlabel('Total Bill')
plt.ylabel('Tip')

plt.show()

# %%
plt.figure(figsize=(10, 8))

sns.scatterplot(x='total_bill', y='tip', hue='time', style='time', data=tips_data)

plt.xlabel('Total Bill')
plt.ylabel('Tip')

plt.show()

# %%
plt.figure(figsize=(10, 8))

sns.scatterplot(x='total_bill', y='tip', 
                hue='day',  
                size='size',
                data=tips_data)

plt.xlabel('Total Bill')
plt.ylabel('Tip')

plt.show()

# %%
plt.figure(figsize=(10, 8))

sns.scatterplot(x='total_bill', y='tip', 
                hue='size',  
                size='size',
                sizes=(30, 300), hue_norm=(0, 7), legend="full",
                data=tips_data)

plt.xlabel('Total Bill')
plt.ylabel('Tip')

plt.show()

# %% [markdown]
# ##### plotting hexbin plot
# Here we have specified sharex = False for showing the x axis labels. If we do not set it false x axis will be invisible

# %%
tips_data.plot.hexbin(x='total_bill', y='tip', 
                      gridsize=15, figsize=(10, 8), sharex=False)

plt.xlabel('Total Bill')
plt.ylabel('Tip')

plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=tips_data, aspect=1.5)

plt.show()

# %%
sns.relplot(x='total_bill', y='tip', kind='line', data=tips_data, aspect=1.5)

plt.show()

# %% [markdown]
# ### Joint Plot
# https://seaborn.pydata.org/generated/seaborn.jointplot.html
#
# As we plot scatter plot above, we can plot the joint plot. In joint plot we can also get the univariate distribution in the form of histogram.

# %%
sns.jointplot(x='total_bill', y='tip', data=tips_data)

plt.show()

# %% [markdown]
# ##### we can also change the limit of x and y axis
# It is same like zoom in the graph

# %%
sns.jointplot(x='total_bill', y='tip', data=tips_data, xlim={0, 40}, ylim={0, 4})

plt.show()

# %% [markdown]
# ### Hexbin Plot
# ##### plotting hexbin plot for Head Size and Brain Weight

# %%
with sns.axes_style('white'):
    sns.jointplot(x='total_bill', y='tip', data=tips_data, kind='hex', color='r')

    plt.show()

# %% [markdown]
# ### Kernel Density Estimation Plot

# %%
sns.jointplot(x='total_bill', y='tip', data=tips_data, kind='kde')

plt.show()

# %% [markdown]
# ##### kde plot can also be drawn by using kdeplot function

# %%
plt.figure(figsize=(10, 8))

sns.kdeplot(tips_data['total_bill'], tips_data['tip'])

plt.show()

# %%
tips_corr = tips_data.corr()

tips_corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips_corr, annot=True)
