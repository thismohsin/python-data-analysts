# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Loading dataset

# %%
admission_data = pd.read_csv('dataset/Admission_Predict.csv')

admission_data.sample(10)
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 491        297           99                  4  3.0   3.5  7.81         0
# 420        299          100                  3  2.0   3.0  7.42         0
# 259        331          119                  4  5.0   4.5  9.34         1
# 96         306          100                  2  3.0   3.0  8.00         0
# 76         327          112                  3  3.0   3.0  8.72         1
# 52         334          116                  4  4.0   3.0  8.00         1
# 399        333          117                  4  5.0   4.0  9.66         1
# 448        312          109                  2  2.5   4.0  9.02         0
# 224        305          105                  2  3.0   2.0  8.23         0
# 247        311          104                  2  2.5   3.5  8.48         0
#
#      Chance of Admit
# 491              0.54
# 420              0.42
# 259              0.90
# 96               0.48
# 76               0.74
# 52               0.78
# 399              0.95
# 448              0.80
# 224              0.67
# 247              0.71

# %% [markdown]
# ### Box Plot
# https://seaborn.pydata.org/generated/seaborn.boxplot.html
# ##### plotting a single boxplot for GRE Score

# %%
plt.figure(figsize=(10, 8))

sns.boxplot(x='GRE Score', data=admission_data)

plt.show()

# %% [markdown]
# ##### change the orientation from horizontal to vertical

# %%
plt.figure(figsize=(10, 8))

sns.boxplot(x='GRE Score', data=admission_data, orient='v')

plt.show()

# %% [markdown]
# ##### plot box plot for time and tip
#
# Here we can figure out that how GRE Score and university rating are related. Students with higher GRE scores tend to apply to universities with higher ratings

# %%
plt.figure(figsize=(10, 8))

sns.boxplot(x='University Rating', y='GRE Score', data=admission_data)

plt.show()

# %% [markdown]
# ##### include the third variable
#
# We can see that student who has done research gets high GRE Score

# %%
plt.figure(figsize=(10, 8))

sns.boxplot(x='University Rating', y='GRE Score', 
            hue='Research', 
            data=admission_data, 
            palette='Set1')

plt.show()

# %% [markdown]
# ##### change the width of the line and we can specify the color in dict

# %%
plt.figure(figsize=(10,8))

sns.boxplot(x='University Rating', y='GRE Score', 
            hue='Research', 
            data=admission_data, 
            palette={'b', 'g'}, 
            linewidth=3)

plt.show()

# %% [markdown]
# ### Violen Plot
# https://seaborn.pydata.org/generated/seaborn.violinplot.html
#
# ##### ploting violen plot for GRE Score
# The plot is thick between 105 and 110 that means most of the students are getting score between 105 and 110

# %%
plt.figure(figsize=(10, 8))

sns.violinplot(x='GRE Score', data=admission_data)

plt.show()

# %% [markdown]
# ##### change the orientation from horizontal to vertical

# %%
plt.figure(figsize=(10, 8))

sns.violinplot(x='GRE Score', data=admission_data, orient='v')

plt.show()

# %% [markdown]
# ##### violin plot for University Rating and TOEFL Score

# %%
plt.figure(figsize=(10, 8))

sns.violinplot(x='University Rating', y='GRE Score', data=admission_data)

plt.show()

# %% [markdown]
# ##### include third variable
# we can figure out students from top universities who had done research are getting higher score

# %%
plt.figure(figsize=(10,8))

sns.violinplot(x='University Rating', y='GRE Score', hue='Research', 
               data=admission_data, palette='Set2')

plt.show()

# %% [markdown]
# ##### draw split violins to compare the across the hue variable

# %%
plt.figure(figsize=(10, 8))

sns.violinplot(x='University Rating', y='GRE Score', hue='Research', 
               data=admission_data, palette='muted', split=True)

plt.show()

# %% [markdown]
# ##### show each datapoint with a stick inside the violin

# %%
plt.figure(figsize=(10, 8))

sns.violinplot(x='University Rating', y='GRE Score', hue='Research', 
               data=admission_data, palette='muted', split=True, inner='stick')

plt.show()

# %% [markdown]
# ##### create a new column for checking the students have CGPA greater than 8.5

# %%
admission_data['First Class'] = admission_data['CGPA'] > 8.5

admission_data.sample(10)
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 102        314          106                  2  4.0   3.5  8.25         0
# 401        315          105                  2  3.0   3.0  8.34         0
# 438        318          110                  1  2.5   3.5  8.54         1
# 66         327          114                  3  3.0   3.0  9.02         0
# 432        324          112                  4  4.5   4.0  9.22         1
# 361        334          116                  4  4.0   3.5  9.54         1
# 473        316          102                  2  4.0   3.5  8.15         0
# 26         322          109                  5  4.5   3.5  8.80         0
# 73         314          108                  4  4.5   4.0  9.04         1
# 312        311          107                  4  4.5   4.5  9.00         1
#
#      Chance of Admit   First Class
# 102              0.62        False
# 401              0.66        False
# 438              0.67         True
# 66               0.61         True
# 432              0.86         True
# 361              0.93         True
# 473              0.67        False
# 26               0.76         True
# 73               0.84         True
# 312              0.78         True

# %% [markdown]
# ##### we can figure out that whether students whose CGPA is greater than 8.5, get a  higher score on their GRE

# %%
plt.figure(figsize=(10, 8))

sns.violinplot(x='University Rating', y='GRE Score', hue='First Class', 
               data=admission_data, dodge=False)

plt.show()

# %% [markdown]
# ##### draw swarms of observations on top of a box plot

# %%
plt.figure(figsize=(10, 8))

sns.boxplot(x='University Rating', y='GRE Score', data=admission_data, whis=np.inf)

sns.swarmplot(x='University Rating', y='GRE Score', data=admission_data, color='black')

plt.show()

# %% [markdown]
# ##### draw swarms of observations on top of a violin plot

# %%
plt.figure(figsize=(10, 8))

sns.violinplot(x='University Rating', y='GRE Score', data=admission_data, inner=None)

sns.swarmplot(x='University Rating', y='GRE Score', data=admission_data, color='w')

plt.show()
