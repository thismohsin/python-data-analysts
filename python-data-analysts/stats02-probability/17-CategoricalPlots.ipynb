# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Loading dataset

# %%
tips_data = pd.read_csv('dataset/tips.csv')

tips_data.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 74        14.73  2.20  Female     No   Sat  Dinner     2
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 69        15.01  2.09    Male    Yes   Sat  Dinner     2
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2
# 171       15.81  3.16    Male    Yes   Sat  Dinner     2
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 201       12.74  2.01  Female    Yes  Thur   Lunch     2
# 227       20.45  3.00    Male     No   Sat  Dinner     4

# %% [markdown]
# ### Bar plot
# https://seaborn.pydata.org/generated/seaborn.barplot.html
# ##### Draw a set of vertical bar plots grouped by categorical variable
#
# Black line is called error bars

# %%
plt.figure(figsize=(10, 8))

sns.barplot(x='size', y='total_bill', data=tips_data)

plt.show()

# %%
plt.figure(figsize=(10, 8))

sns.barplot(x='size', y='tip', data=tips_data)

plt.show()

# %%
plt.figure(figsize=(10, 8))

sns.countplot(x='size', data=tips_data)

plt.show()

# %% [markdown]
# ##### Draw a set of vertical bars with nested grouping by a two variables

# %%
plt.figure(figsize=(10, 8))

sns.barplot(x='size', y='total_bill', data=tips_data, hue='smoker')

plt.show()

# %% [markdown]
# ##### Use median as the estimate of central tendency

# %%
plt.figure(figsize=(10, 8))

sns.barplot(x='size', y='total_bill', data=tips_data, estimator=np.median)

plt.show()

# %% [markdown]
# ##### Show standard deviation of observations instead of a confidence interval

# %%
plt.figure(figsize=(10, 8))

sns.barplot(x='size', y='total_bill', data=tips_data, ci='sd')

plt.show()

# %% [markdown]
# ##### Add “caps” to the error bars

# %%
plt.figure(figsize=(10, 8))

sns.barplot(x='size', y='total_bill', data=tips_data, capsize=0.2)

plt.show()

# %% [markdown]
# ##### Use a different color palette for the bars

# %%
plt.figure(figsize=(10, 8))

sns.barplot(x='size', y='total_bill', data=tips_data, palette='Reds_r')

plt.show()

# %% [markdown]
# ##### adding one more column for checking size is 2

# %%
tips_data['couple'] = tips_data['size'] == 2

# %%
tips_data.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size  couple
# 62        11.02  1.98    Male    Yes   Sat  Dinner     2    True
# 24        19.82  3.18    Male     No   Sat  Dinner     2    True
# 239       29.03  5.92    Male     No   Sat  Dinner     3   False
# 40        16.04  2.24    Male     No   Sat  Dinner     3   False
# 184       40.55  3.00    Male    Yes   Sun  Dinner     2    True
# 176       17.89  2.00    Male    Yes   Sun  Dinner     2    True
# 164       17.51  3.00  Female    Yes   Sun  Dinner     2    True
# 113       23.95  2.55    Male     No   Sun  Dinner     2    True
# 87        18.28  4.00    Male     No  Thur   Lunch     2    True
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4   False

# %% [markdown]
# ##### Use hue without changing bar position or width

# %%
plt.figure(figsize=(10, 8))

sns.barplot(x='size', y='total_bill', data=tips_data, hue='couple', dodge=False)

plt.show()

# %% [markdown]
# ### Point plot
# https://seaborn.pydata.org/generated/seaborn.pointplot.html
# Point plot specify an estimate of the central tendency of a varaible and confidence around central tendency

# %%
plt.figure(figsize=(10, 8))

sns.pointplot(x='size', y='total_bill', data=tips_data)

plt.show()

# %% [markdown]
# ##### Separate the points for different hue levels along the categorical axis

# %%
plt.figure(figsize=(10, 8))

sns.pointplot(x='size', y='total_bill', data=tips_data, hue='sex')

plt.show()

# %% [markdown]
# ##### Use a different marker and line style for the hue levels

# %%
plt.figure(figsize=(10, 8))

sns.pointplot(x='size', y='total_bill', data=tips_data, 
              hue='sex', markers=['o', 's'], linestyles=['-', '--'])

plt.show()

# %% [markdown]
# ### Factorplot or catplot
# https://seaborn.pydata.org/generated/seaborn.catplot.html

# %%
sns.catplot(x='day', y='total_bill', kind='box', data = tips_data, aspect=1.5)

plt.show()

# %% [markdown]
# ##### plot catplot for size and total_bill
#
# It shows the relationship between a numerical and one or more categorical variables.

# %%
sns.catplot(x='size', y='total_bill', hue='time', data=tips_data, 
            height=5, aspect=1.5)

plt.show()

# %% [markdown]
# ##### use a different plot kind to visualize the same data

# %%
sns.catplot(x='size', y='total_bill', hue='time', data=tips_data, 
            kind='violin', height=5, aspect=1.5)

plt.show()

# %% [markdown]
# ##### using a third categorical variable and dividing it with the columns

# %%
sns.catplot(x='size', y='total_bill', hue='time', data=tips_data, 
            col='smoker', height=5, aspect=1)

plt.show()

# %% [markdown]
# ##### make many column and wrap them into the rows of the grid

# %%
sns.catplot('smoker', col='day', data=tips_data, 
            col_wrap=2, kind='count', height=3, aspect=1)

plt.show()
