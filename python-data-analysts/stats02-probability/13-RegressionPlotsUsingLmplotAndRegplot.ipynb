# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading dataset
#
# #### Seaborn_tips_dataset
# Source: https://www.kaggle.com/ranjeetjain3/seaborn-tips-dataset

# %%
tips_data = pd.read_csv('dataset/tips.csv')

tips_data.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 199       13.51  2.00    Male    Yes  Thur   Lunch     2
# 70        12.02  1.97    Male     No   Sat  Dinner     2
# 192       28.44  2.56    Male    Yes  Thur   Lunch     2
# 184       40.55  3.00    Male    Yes   Sun  Dinner     2
# 146       18.64  1.36  Female     No  Thur   Lunch     3
# 187       30.46  2.00    Male    Yes   Sun  Dinner     5
# 106       20.49  4.06    Male    Yes   Sat  Dinner     2
# 82        10.07  1.83  Female     No  Thur   Lunch     1
# 26        13.37  2.00    Male     No   Sat  Dinner     2

# %% [markdown]
# ##### shape of dataset (rows, columns)

# %%
tips_data.shape
# Out:
# (244, 7)

# %% [markdown]
# ### Lmplot
# https://seaborn.pydata.org/generated/seaborn.lmplot.html
# ##### plotting Lmplot for total_bill and tip

# %%
sns.lmplot(x='total_bill', y='tip', data=tips_data, aspect=1.5)

plt.show()

# %% [markdown]
# ##### plotting lmplot for total_bill and tip with hue = smoker
#
# where hue is variable that define subsets of the data, which will be drawn on separate facets in the grid.

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', data=tips_data, aspect=1.5)

plt.show()

# %% [markdown]
# ##### this time we are defining the markers also

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', data=tips_data, 
           markers=['o','x'], aspect=1.5)

plt.show()

# %% [markdown]
# ##### here we specified palette = 'Set1'
# where palette is for colors to use for the different levels of the hue variable.

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker',data=tips_data, 
           palette='Set1', aspect=1.5)

plt.show()

# %% [markdown]
# ##### Map hue levels to colors with a dictionary

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker',data=tips_data, 
           palette=dict(Yes='r', No='k'), aspect=1.5)

plt.show()

# %%
sns.lmplot(x='size', y='tip', data=tips_data, aspect=1.5)

plt.show()

# %% [markdown]
# ##### here we are adding some jitter and we can see the regression line is not effected by jitter

# %%
sns.lmplot(x='size', y='tip', data=tips_data, aspect=1.5, x_jitter=0.2)

plt.show()

# %% [markdown]
# ##### Plot the levels of the third variable across different column

# %%
sns.lmplot(x='total_bill', y='tip', data=tips_data, col='smoker')

plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', data=tips_data, 
           hue='day', col='day', height=5, aspect=0.8)

plt.show()

# %% [markdown]
# ##### Wrap the levels of the column variable into multiple rows

# %%
sns.lmplot(x='total_bill', y='tip', data=tips_data, 
           hue='day', col='day', 
           height=3, col_wrap=2, aspect=1.5)

plt.show()

# %% [markdown]
# ##### Condition on two variables to make a full grid

# %%
sns.lmplot(x='total_bill', y='tip', data=tips_data, 
           col='time', row='smoker', 
           height=3, aspect=1.5)

plt.show()

# %% [markdown]
# ##### here we are adding x and y labels and limits

# %%
sns.lmplot(x='total_bill', y='tip', data=tips_data, 
           col='time', row='smoker', 
           hue='time',
           height=3, aspect=1.5)

plt.show()

# %% [markdown]
# ### Regplot
# https://seaborn.pydata.org/generated/seaborn.regplot.html
# Regplot is another type of regression plot. The main difference between regplot and lmplot is lmplot is figure level function and regplot is axes level function.
# ##### ploting regplot for total_bill and tip

# %%
plt.figure(figsize=(10, 8))

sns.regplot(x='total_bill', y='tip', data=tips_data)

plt.show()

# %% [markdown]
# ##### this time ploting with different color and marker and we are entering the data as pandas series

# %%
plt.figure(figsize=(10, 8))

sns.regplot(tips_data['total_bill'], tips_data['tip'], color='b', marker='*')

plt.show()

# %% [markdown]
# ##### this time we are plotting with categorical values

# %%
plt.figure(figsize=(10, 8))

sns.regplot(x='size', y='total_bill', data=tips_data, 
            color='b', x_jitter=0.1)

plt.show()

# %% [markdown]
# ##### plotting with a continuous variable divided into discrete bin

# %%
plt.figure(figsize=(10, 8))

sns.regplot(x='total_bill', y='tip', data=tips_data, color='b', x_bins=4)

plt.show()

# %% [markdown]
# ##### Fit the regression model using log(x)

# %%
plt.figure(figsize=(10, 8))

sns.regplot(x='size', y='total_bill', data=tips_data, color='b', 
            x_estimator=np.mean, logx=True, truncate=True)

plt.show()

# %% [markdown]
# ##### adding a new column that tells about whether it is a big tip

# %%
tips_data['big_tip'] = (tips_data.tip / tips_data.total_bill) > 0.175

tips_data.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size  big_tip
# 107       25.21  4.29    Male    Yes   Sat  Dinner     2    False
# 192       28.44  2.56    Male    Yes  Thur   Lunch     2    False
# 27        12.69  2.00    Male     No   Sat  Dinner     2    False
# 106       20.49  4.06    Male    Yes   Sat  Dinner     2     True
# 99        12.46  1.50    Male     No   Fri  Dinner     2    False
# 196       10.34  2.00    Male    Yes  Thur   Lunch     2     True
# 232       11.61  3.39    Male     No   Sat  Dinner     2     True
# 19        20.65  3.35    Male     No   Sat  Dinner     3    False
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2    False
# 70        12.02  1.97    Male     No   Sat  Dinner     2    False

# %%
plt.figure(figsize=(10, 8))

sns.regplot(x='total_bill', y='big_tip', data=tips_data, logistic=True, y_jitter=0.01)

plt.show()
