# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Loading dataset

# %%
tips_data = pd.read_csv('dataset/tips.csv')

tips_data.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 65        20.08  3.15    Male     No   Sat  Dinner     3
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 126        8.52  1.48    Male     No  Thur   Lunch     2
# 177       14.48  2.00    Male    Yes   Sun  Dinner     2
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 201       12.74  2.01  Female    Yes  Thur   Lunch     2
# 43         9.68  1.32    Male     No   Sun  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2

# %% [markdown]
# ### Strip Plot
# https://seaborn.pydata.org/generated/seaborn.stripplot.html

# %%
plt.figure(figsize=(10, 8))

sns.stripplot(x='sex', y='tip', data= tips_data)

plt.show()

# %% [markdown]
# ##### plot for jitter = False

# %%
plt.figure(figsize=(10, 8))

sns.stripplot(x='sex', y='tip', data=tips_data, jitter=False)

plt.show()

# %% [markdown]
# ##### plot for jitter = 0.04

# %%
plt.figure(figsize=(10, 8))

sns.stripplot(x='sex', y='tip', data= tips_data, jitter=0.04)

plt.show()

# %% [markdown]
# ##### plotting stripplot for day and tip
#
# we can figure out that on sat and sum peoples are giving more tip and on sunday some people have given highest prize as tip

# %%
plt.figure(figsize=(10, 8))

sns.stripplot(x='day', y='tip', data= tips_data, jitter=0.04)

plt.show()

# %% [markdown]
# ##### plotting for size and tip

# %%
plt.figure(figsize=(10, 8))

sns.stripplot(x='size', y='tip', data= tips_data, jitter=0.04)

plt.show()

# %% [markdown]
# ### Swarm Plot
# https://seaborn.pydata.org/generated/seaborn.swarmplot.html
# This plot spreads out the points at every categorical value so that the overlap is minimum
#
# Here we are plotting only for one variable and we can see most of the tips are $2

# %%
plt.figure(figsize=(10, 8))

sns.swarmplot(x='tip', data=tips_data)

plt.show()

# %% [markdown]
# ##### ploting swarm plot for size and tip

# %%
plt.figure(figsize=(10, 8))

sns.swarmplot(x='size', y='tip', data=tips_data)

plt.show()

# %% [markdown]
# ##### color the points according to male , female

# %%
plt.figure(figsize=(10, 8))

sns.swarmplot(x='size', y='tip', hue='sex', data=tips_data)

plt.show()

# %% [markdown]
# ##### this time dodge = True to separate the strips

# %%
plt.figure(figsize=(10, 8))

sns.swarmplot(x='size', y='tip', hue='sex', data=tips_data, palette='Set1', dodge=True)

plt.show()

# %% [markdown]
# ##### we change the size of the points also

# %%
plt.figure(figsize=(10, 8))

sns.swarmplot(x='size', y='tip', hue='sex', data=tips_data, 
              palette='Set1', dodge=True, size=8)

plt.show()

# %% [markdown]
# ##### we can choose the order of the size

# %%
plt.figure(figsize=(10, 8))

sns.swarmplot(x='size', 
              y='tip', 
              hue='sex', 
              data=tips_data, 
              palette='Set1', 
              dodge=True, 
              order=[2, 4, 3, 5, 6, 1])

plt.show()
