# %%
import pandas as pd

# %% [markdown]
# ## conversion types

# %%
data = pd.read_csv("artwork_sample.csv")

# %%
data.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
data.dtypes
# Out:
# id                      int64
# accession_number       object
# artist                 object
# artistRole             object
# artistId                int64
# title                  object
# dateText               object
# medium                 object
# creditLine             object
# year                  float64
# acquisitionYear         int64
# dimensions             object
# width                   int64
# height                  int64
# depth                 float64
# units                  object
# inscription           float64
# thumbnailCopyright    float64
# thumbnailUrl           object
# url                    object
# dtype: object

# %%
data.acquisitionYear
# Out:
# 0    1922
# 1    1922
# 2    1922
# 3    1922
# 4    1919
# 5    1919
# 6    1919
# 7    1919
# 8    1919
# 9    1919
# Name: acquisitionYear, dtype: int64

# %%
data.acquisitionYear.astype(float)
# Out:
# 0    1922.0
# 1    1922.0
# 2    1922.0
# 3    1922.0
# 4    1919.0
# 5    1919.0
# 6    1919.0
# 7    1919.0
# 8    1919.0
# 9    1919.0
# Name: acquisitionYear, dtype: float64

# %%
data.acquisitionYear.dtype
# Out:
# dtype('int64')

# %%
data.acquisitionYear=data.acquisitionYear.astype(float)

# %%
data.acquisitionYear.dtype
# Out:
# dtype('float64')

# %%
fulldf = pd.read_csv('artwork_data.csv', low_memory=False)

# %%
fulldf.dtypes
# Out:
# id                      int64
# accession_number       object
# artist                 object
# artistRole             object
# artistId                int64
# title                  object
# dateText               object
# medium                 object
# creditLine             object
# year                   object
# acquisitionYear       float64
# dimensions             object
# width                  object
# height                 object
# depth                 float64
# units                  object
# inscription            object
# thumbnailCopyright     object
# thumbnailUrl           object
# url                    object
# dtype: object

# %%
fulldf.height.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/06/zb4xx4b50dj3tdm_y49gwy640000gn/T/ipykernel_74286/1535406240.py in <module>
# ----> 1 fulldf.height.astype(float)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
# ...

# %%
pd.to_numeric(fulldf.height)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "mm"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/06/zb4xx4b50dj3tdm_y49gwy640000gn/T/ipykernel_74286/2008045044.py in <module>
# ----> 1 pd.to_numeric(fulldf.height)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ...

# %%
pd.to_numeric(fulldf.height, errors="coerce")
# Out:
# 0         419.0
# 1         213.0
# 2         467.0
# 3         394.0
# 4         335.0
#           ...
# 69196     305.0
# 69197     305.0
# 69198    2410.0
# 69199       NaN
# 69200     660.0
# Name: height, Length: 69201, dtype: float64

# %%
pd.to_numeric(fulldf.height, errors="coerce")[41339]
# Out:
# nan

# %%
fulldf.height.dtype
# Out:
# dtype('O')

# %%
fulldf.height = pd.to_numeric(fulldf.height, errors="coerce")

# %%
fulldf.height.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Aggregate

# %%
data.year
# Out:
# 0       NaN
# 1       NaN
# 2    1785.0
# 3       NaN
# 4    1826.0
# 5    1826.0
# 6    1826.0
# 7    1826.0
# 8    1826.0
# 9    1826.0
# Name: year, dtype: float64

# %%
data.year.min()
# Out:
# 12741.0

# %%
data.year.std()
# Out:
# 15.496543393378316

# %%
data.year.sum()
# Out:
# 12741.0

# %%
data.year.mean()
# Out:
# 1820.142857142857

# %%
data.artist.min()
# Out:
# 'Blake, Robert'

# %%
data.artist.sum()
# Out:
# 'Blake, RobertBlake, RobertBlake, RobertBlake, RobertBlake, WilliamBlake, WilliamBlake, WilliamBlake, WilliamBlake, WilliamBlake, William'

# %%
data.agg('min')
# Out:
# id                                                                 1035
# accession_number                                                 A00001
# artist                                                    Blake, Robert
# artistRole                                                       artist
# artistId                                                             38
# title                 A Figure Bowing before a Seated Old Man with h...
# dateText                                         1826–7, reprinted 1892
# medium                                                Graphite on paper
# creditLine                          Presented by Mrs John Richmond 1922
# year                                                             1785.0
# acquisitionYear                                                  1919.0
# dimensions                                          image: 240 x 338 mm
# width                                                               240
# ...

# %%
data.agg(['min','max','mean', 'std'])
# Out:
#               id accession_number          artist artistRole   artistId  \
# min   1035.00000           A00001   Blake, Robert     artist  38.000000
# max   1044.00000           A00010  Blake, William     artist  39.000000
# mean  1039.50000              NaN             NaN        NaN  38.600000
# std      3.02765              NaN             NaN        NaN   0.516398
#
#                                                   title  \
# min   A Figure Bowing before a Seated Old Man with h...
# max   Two Drawings of Frightened Figures, Probably f...
# mean                                                NaN
# std                                                 NaN
#
#                     dateText  \
# min   1826–7, reprinted 1892
# max           date not known
# mean                     NaN
# std                      NaN
#
#                                                  medium  \
# min                                   Graphite on paper
# ...

# %%
data.agg('mean',axis="columns")

# %% [markdown]
# ### normalizing

# %%
data.dtypes #only int64/float
# Out:
# id                      int64
# accession_number       object
# artist                 object
# artistRole             object
# artistId                int64
# title                  object
# dateText               object
# medium                 object
# creditLine             object
# year                  float64
# acquisitionYear       float64
# dimensions             object
# width                   int64
# height                  int64
# depth                 float64
# units                  object
# inscription           float64
# thumbnailCopyright    float64
# thumbnailUrl           object
# url                    object
# dtype: object

# %%
data.height.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0    419
# 1    213
# 2    467
# 3    394
# 4    335
# 5    338
# 6    334
# 7    340
# 8    335
# 9    340
# Name: height, dtype: int64>

# %%
height = data.height

# %%
norm = (height - height.mean())/height.std()
norm ## standardization
# Out:
# 0    1.010198
# 1   -2.072777
# 2    1.728561
# 3    0.636051
# 4   -0.246937
# 5   -0.202040
# 6   -0.261903
# 7   -0.172108
# 8   -0.246937
# 9   -0.172108
# Name: height, dtype: float64

# %%
# range-minmax
minmax = (height-height.min())/(height.max()-height.min())
minmax
# Out:
# 0    0.811024
# 1    0.000000
# 2    1.000000
# 3    0.712598
# 4    0.480315
# 5    0.492126
# 6    0.476378
# 7    0.500000
# 8    0.480315
# 9    0.500000
# Name: height, dtype: float64

# %%
minmax.min()
# Out:
# 0.0

# %%
minmax.max()
# Out:
# 1.0

# %%
data #no effect
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %%
#data.height=minmax
data['ht_std_value'] = norm
data['ht_minmax_value'] = norm

# %%
data
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %% [markdown]
# ## transforming data

# %%
data.height.transform(lambda x : print(x))
# Out:
# 419
# 213
# 467
# 394
# 335
# 338
# 334
# 340
# 335
# 340
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# 5    None
# 6    None
# 7    None
# 8    None
# 9    None
# Name: height, dtype: object

# %%
data.height.transform(lambda x : x)
# Out:
# 0    419
# 1    213
# 2    467
# 3    394
# 4    335
# 5    338
# 6    334
# 7    340
# 8    335
# 9    340
# Name: height, dtype: int64

# %%
data.height.transform(lambda x : x/10)
# Out:
# 0    41.9
# 1    21.3
# 2    46.7
# 3    39.4
# 4    33.5
# 5    33.8
# 6    33.4
# 7    34.0
# 8    33.5
# 9    34.0
# Name: height, dtype: float64

# %%
data.groupby('artist')

# %%
data.groupby('artist').transform('nunique') ## count of number unique val per row per column group by artist
# Out:
#    id  accession_number  artistRole  artistId  title  dateText  medium  \
# 0   4                 4           1         1      4         2       3
# 1   4                 4           1         1      4         2       3
# 2   4                 4           1         1      4         2       3
# 3   4                 4           1         1      4         2       3
# 4   6                 6           1         1      6         1       1
# 5   6                 6           1         1      6         1       1
# 6   6                 6           1         1      6         1       1
# 7   6                 6           1         1      6         1       1
# 8   6                 6           1         1      6         1       1
# 9   6                 6           1         1      6         1       1
#
#    creditLine  year  acquisitionYear  ...  width  height  depth  units  \
# 0           1     1                1  ...      4       4      0      1
# ...

# %%
data.groupby('artist')['height']

# %%
data.groupby('artist')['height'].transform('mean')
# Out:
# 0    373.25
# 1    373.25
# 2    373.25
# 3    373.25
# 4    337.00
# 5    337.00
# 6    337.00
# 7    337.00
# 8    337.00
# 9    337.00
# Name: height, dtype: float64

# %%
data['mean_ht_by_artist'] = data.groupby('artist')['height'].transform('mean')

# %%
data
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %%
# del data['min_ht_by_artist'] to drop column

# %% [markdown]
# ## filtering

# %%
data.filter(items=['id','artist'])
# Out:
#      id          artist
# 0  1035   Blake, Robert
# 1  1036   Blake, Robert
# 2  1037   Blake, Robert
# 3  1038   Blake, Robert
# 4  1039  Blake, William
# 5  1040  Blake, William
# 6  1041  Blake, William
# 7  1042  Blake, William
# 8  1043  Blake, William
# 9  1044  Blake, William

# %%
data.filter(like='year')  # artist
# Out:
#      year
# 0     NaN
# 1     NaN
# 2  1785.0
# 3     NaN
# 4  1826.0
# 5  1826.0
# 6  1826.0
# 7  1826.0
# 8  1826.0
# 9  1826.0

# %%
data.filter(regex="(?i)year")  # case insensitive
# Out:
#      year  acquisitionYear
# 0     NaN           1922.0
# 1     NaN           1922.0
# 2  1785.0           1922.0
# 3     NaN           1922.0
# 4  1826.0           1919.0
# 5  1826.0           1919.0
# 6  1826.0           1919.0
# 7  1826.0           1919.0
# 8  1826.0           1919.0
# 9  1826.0           1919.0

# %%
data.filter(axis=0, regex="(0|2|4|6|8)") ## axis=0 row and axis=1 column
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
# 6                        The Baffled Devils Fighting  1826–7, reprinted 1892
# 8                 The Serpent Attacking Buoso Donati  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
data
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %% [markdown]
# ## column operation

# %%
data.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
data.drop(0) #drop row
# Out:
#      id accession_number          artist artistRole  artistId  \
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# ...

# %%
data.drop('id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/06/zb4xx4b50dj3tdm_y49gwy640000gn/T/ipykernel_74286/3440589647.py in <module>
# ----> 1 data.drop('id')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
data.drop('id',axis=1) #column
# Out:
#   accession_number          artist artistRole  artistId  \
# 0           A00001   Blake, Robert     artist        38
# 1           A00002   Blake, Robert     artist        38
# 2           A00003   Blake, Robert     artist        38
# 3           A00004   Blake, Robert     artist        38
# 4           A00005  Blake, William     artist        39
# 5           A00006  Blake, William     artist        39
# 6           A00007  Blake, William     artist        39
# 7           A00008  Blake, William     artist        39
# 8           A00009  Blake, William     artist        39
# 9           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# ...

# %%
data.drop(columns=['id'])
# Out:
#   accession_number          artist artistRole  artistId  \
# 0           A00001   Blake, Robert     artist        38
# 1           A00002   Blake, Robert     artist        38
# 2           A00003   Blake, Robert     artist        38
# 3           A00004   Blake, Robert     artist        38
# 4           A00005  Blake, William     artist        39
# 5           A00006  Blake, William     artist        39
# 6           A00007  Blake, William     artist        39
# 7           A00008  Blake, William     artist        39
# 8           A00009  Blake, William     artist        39
# 9           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# ...

# %%
data.drop(labels=[0,1,2])
# Out:
#      id accession_number          artist artistRole  artistId  \
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
# 5      Ciampolo the Barrator Tormented by the Devils  1826–7, reprinted 1892
# 6                        The Baffled Devils Fighting  1826–7, reprinted 1892
# 7  The Six-Footed Serpent Attacking Agnolo Brunel...  1826–7, reprinted 1892
# ...

# %%
data # all original intact  - each operation returns new dataframe and not change original one
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %%
data.drop(columns=['id'], inplace=True)

# %%
data # gone
# Out:
#   accession_number          artist artistRole  artistId  \
# 0           A00001   Blake, Robert     artist        38
# 1           A00002   Blake, Robert     artist        38
# 2           A00003   Blake, Robert     artist        38
# 3           A00004   Blake, Robert     artist        38
# 4           A00005  Blake, William     artist        39
# 5           A00006  Blake, William     artist        39
# 6           A00007  Blake, William     artist        39
# 7           A00008  Blake, William     artist        39
# 8           A00009  Blake, William     artist        39
# 9           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# ...

# %%
data = pd.read_csv("artwork_sample.csv", usecols=['artist'])
data
# Out:
#            artist
# 0   Blake, Robert
# 1   Blake, Robert
# 2   Blake, Robert
# 3   Blake, Robert
# 4  Blake, William
# 5  Blake, William
# 6  Blake, William
# 7  Blake, William
# 8  Blake, William
# 9  Blake, William

# %%
data = pd.read_csv("artwork_sample.csv")

# %%
data.columns.str.lower()
# Out:
# Index(['id', 'accession_number', 'artist', 'artistrole', 'artistid', 'title',
#        'datetext', 'medium', 'creditline', 'year', 'acquisitionyear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailcopyright', 'thumbnailurl', 'url'],
#       dtype='object')

# %%
data.columns=[x.lower() for x in data.columns]

# %%
data
# Out:
#      id accession_number          artist artistrole  artistid  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                datetext  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %%
data.columns = map(lambda  x:x.upper(), data.columns)
data
# Out:
#      ID ACCESSION_NUMBER          ARTIST ARTISTROLE  ARTISTID  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                TITLE                DATETEXT  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %%
data.columns
# Out:
# Index(['ID', 'ACCESSION_NUMBER', 'ARTIST', 'ARTISTROLE', 'ARTISTID', 'TITLE',
#        'DATETEXT', 'MEDIUM', 'CREDITLINE', 'YEAR', 'ACQUISITIONYEAR',
#        'DIMENSIONS', 'WIDTH', 'HEIGHT', 'DEPTH', 'UNITS', 'INSCRIPTION',
#        'THUMBNAILCOPYRIGHT', 'THUMBNAILURL', 'URL'],
#       dtype='object')

# %%
data.rename(columns={'THUMBNAILURL':'thumbnail'}) ## inplace=True
# Out:
#      ID ACCESSION_NUMBER          ARTIST ARTISTROLE  ARTISTID  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                TITLE                DATETEXT  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %%
data.rename(columns=lambda x:x.lower(), inplace=True)
data
# Out:
#      id accession_number          artist artistrole  artistid  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                datetext  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %%
data.columns
# Out:
# Index(['id', 'accession_number', 'artist', 'artistrole', 'artistid', 'title',
#        'datetext', 'medium', 'creditline', 'year', 'acquisitionyear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailcopyright', 'thumbnailurl', 'url'],
#       dtype='object')

# %%
data.columns=['id', 'accession_number', 'artist', 'artistrole', 'artistid', 'title',
              'datetext', 'medium', 'creditline', 'year', 'acquisitionyear',
              'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
              'thumbnailcopyright', 'thumbnailurl', 'url']

# %%
data = pd.read_csv('artwork_sample.csv',names=['id', 'accession_number', 'artist', 'artistrole', 'artistid', 'title',
                                          'datetext', 'medium', 'creditline', 'year', 'acquisitionyear',
                                          'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
                                          'thumbnailcopyright', 'thumbnailurl', 'url'], header=0)

# %%
data
# Out:
#      id accession_number          artist artistrole  artistid  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                datetext  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %% [markdown]
# ## indexing and filtering dataset

# %%
data['id']
# Out:
# 0    1035
# 1    1036
# 2    1037
# 3    1038
# 4    1039
# 5    1040
# 6    1041
# 7    1042
# 8    1043
# 9    1044
# Name: id, dtype: int64

# %%
data['id'][1]
# Out:
# 1036

# %%
data[['artist','title']] # not recommended
# Out:
#            artist                                              title
# 0   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1   Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 2   Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 3   Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 4  Blake, William  The Circle of the Lustful: Francesca da Rimini...
# 5  Blake, William      Ciampolo the Barrator Tormented by the Devils
# 6  Blake, William                        The Baffled Devils Fighting
# 7  Blake, William  The Six-Footed Serpent Attacking Agnolo Brunel...
# 8  Blake, William                 The Serpent Attacking Buoso Donati
# 9  Blake, William                 The Pit of Disease: The Falsifiers

# %%
data[['artist','title']][1] #cannot access dataframe index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data[['artist','title']]['artist'][1] ## df return series and can access
# Out:
# 'Blake, Robert'

# %%
data[1:4] # incl:excl
# Out:
#      id accession_number         artist artistrole  artistid  \
# 1  1036           A00002  Blake, Robert     artist        38
# 2  1037           A00003  Blake, Robert     artist        38
# 3  1038           A00004  Blake, Robert     artist        38
#
#                                                title        datetext  \
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
# 2  The Preaching of Warning. Verso: An Old Man En...         ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms  date not known
#
#                                         medium  \
# 1                            Graphite on paper
# 2  Graphite on paper. Verso: graphite on paper
# 3                            Graphite on paper
#
#                             creditline    year  acquisitionyear  \
# 1  Presented by Mrs John Richmond 1922     NaN             1922
# 2  Presented by Mrs John Richmond 1922  1785.0             1922
# ...

# %%
data[1:4]['id']
# Out:
# 1    1036
# 2    1037
# 3    1038
# Name: id, dtype: int64

# %%
data[data['year'] > 1800]
# Out:
#      id accession_number          artist artistrole  artistid  \
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                datetext  \
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
# 5      Ciampolo the Barrator Tormented by the Devils  1826–7, reprinted 1892
# 6                        The Baffled Devils Fighting  1826–7, reprinted 1892
# 7  The Six-Footed Serpent Attacking Agnolo Brunel...  1826–7, reprinted 1892
# 8                 The Serpent Attacking Buoso Donati  1826–7, reprinted 1892
# ...

# %%
data[data['year'] > 1800]['year']
# Out:
# 4    1826.0
# 5    1826.0
# 6    1826.0
# 7    1826.0
# 8    1826.0
# 9    1826.0
# Name: year, dtype: float64

# %%
data.loc[0,:] # r,c and incls
# Out:
# id                                                                 1035
# accession_number                                                 A00001
# artist                                                    Blake, Robert
# artistrole                                                       artist
# artistid                                                             38
# title                 A Figure Bowing before a Seated Old Man with h...
# datetext                                                 date not known
# medium                Watercolour, ink, chalk and graphite on paper....
# creditline                          Presented by Mrs John Richmond 1922
# year                                                                NaN
# acquisitionyear                                                    1922
# dimensions                                        support: 394 x 419 mm
# width                                                               394
# ...

# %%
data.loc[0:2,:]
# Out:
#      id accession_number         artist artistrole  artistid  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
# 2  1037           A00003  Blake, Robert     artist        38
#
#                                                title        datetext  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
# 2  The Preaching of Warning. Verso: An Old Man En...         ?c.1785
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# 2        Graphite on paper. Verso: graphite on paper
#
#                             creditline    year  acquisitionyear  \
# 0  Presented by Mrs John Richmond 1922     NaN             1922
# 1  Presented by Mrs John Richmond 1922     NaN             1922
# ...

# %%
data.loc[0:2]
# Out:
#      id accession_number         artist artistrole  artistid  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
# 2  1037           A00003  Blake, Robert     artist        38
#
#                                                title        datetext  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
# 2  The Preaching of Warning. Verso: An Old Man En...         ?c.1785
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# 2        Graphite on paper. Verso: graphite on paper
#
#                             creditline    year  acquisitionyear  \
# 0  Presented by Mrs John Richmond 1922     NaN             1922
# 1  Presented by Mrs John Richmond 1922     NaN             1922
# ...

# %%
data.loc[0:2,'title']
# Out:
# 0    A Figure Bowing before a Seated Old Man with h...
# 1    Two Drawings of Frightened Figures, Probably f...
# 2    The Preaching of Warning. Verso: An Old Man En...
# Name: title, dtype: object

# %%
data.loc[0:2,['title','artist']]
# Out:
#                                                title         artist
# 0  A Figure Bowing before a Seated Old Man with h...  Blake, Robert
# 1  Two Drawings of Frightened Figures, Probably f...  Blake, Robert
# 2  The Preaching of Warning. Verso: An Old Man En...  Blake, Robert

# %%
data.loc[[1,5],['title','artist']]
# Out:
#                                                title          artist
# 1  Two Drawings of Frightened Figures, Probably f...   Blake, Robert
# 5      Ciampolo the Barrator Tormented by the Devils  Blake, William

# %%
data.loc[[1,5],'id':'artistid']
# Out:
#      id accession_number          artist artistrole  artistid
# 1  1036           A00002   Blake, Robert     artist        38
# 5  1040           A00006  Blake, William     artist        39

# %%
data.loc[data.artist=='Blake, Robert', :]
# Out:
#      id accession_number         artist artistrole  artistid  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
# 2  1037           A00003  Blake, Robert     artist        38
# 3  1038           A00004  Blake, Robert     artist        38
#
#                                                title        datetext  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
# 2  The Preaching of Warning. Verso: An Old Man En...         ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# 2        Graphite on paper. Verso: graphite on paper
# 3                                  Graphite on paper
#
# ...

# %%
data.loc[data.artist=='Blake, Robert', ['title','artist']]
# Out:
#                                                title         artist
# 0  A Figure Bowing before a Seated Old Man with h...  Blake, Robert
# 1  Two Drawings of Frightened Figures, Probably f...  Blake, Robert
# 2  The Preaching of Warning. Verso: An Old Man En...  Blake, Robert
# 3     Six Drawings of Figures with Outstretched Arms  Blake, Robert

# %%
data.iloc[0,:]
# Out:
# id                                                                 1035
# accession_number                                                 A00001
# artist                                                    Blake, Robert
# artistrole                                                       artist
# artistid                                                             38
# title                 A Figure Bowing before a Seated Old Man with h...
# datetext                                                 date not known
# medium                Watercolour, ink, chalk and graphite on paper....
# creditline                          Presented by Mrs John Richmond 1922
# year                                                                NaN
# acquisitionyear                                                    1922
# dimensions                                        support: 394 x 419 mm
# width                                                               394
# ...

# %%
data.iloc[0:3,:]
# Out:
#      id accession_number         artist artistrole  artistid  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
# 2  1037           A00003  Blake, Robert     artist        38
#
#                                                title        datetext  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
# 2  The Preaching of Warning. Verso: An Old Man En...         ?c.1785
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# 2        Graphite on paper. Verso: graphite on paper
#
#                             creditline    year  acquisitionyear  \
# 0  Presented by Mrs John Richmond 1922     NaN             1922
# 1  Presented by Mrs John Richmond 1922     NaN             1922
# ...

# %%
data.set_index('id', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/06/zb4xx4b50dj3tdm_y49gwy640000gn/T/ipykernel_74286/2840349668.py in <module>
# ----> 1 data.set_index('id', inplace=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['id'] are in the columns"

# %%
data
# Out:
#      accession_number          artist artistrole  artistid  \
# id
# 1035           A00001   Blake, Robert     artist        38
# 1036           A00002   Blake, Robert     artist        38
# 1037           A00003   Blake, Robert     artist        38
# 1038           A00004   Blake, Robert     artist        38
# 1039           A00005  Blake, William     artist        39
# 1040           A00006  Blake, William     artist        39
# 1041           A00007  Blake, William     artist        39
# 1042           A00008  Blake, William     artist        39
# 1043           A00009  Blake, William     artist        39
# 1044           A00010  Blake, William     artist        39
#
#                                                   title  \
# id
# 1035  A Figure Bowing before a Seated Old Man with h...
# 1036  Two Drawings of Frightened Figures, Probably f...
# 1037  The Preaching of Warning. Verso: An Old Man En...
# 1038     Six Drawings of Figures with Outstretched Arms
# ...

# %%
data.iloc[0:3,:]
# Out:
#      accession_number         artist artistrole  artistid  \
# id
# 1035           A00001  Blake, Robert     artist        38
# 1036           A00002  Blake, Robert     artist        38
# 1037           A00003  Blake, Robert     artist        38
#
#                                                   title        datetext  \
# id
# 1035  A Figure Bowing before a Seated Old Man with h...  date not known
# 1036  Two Drawings of Frightened Figures, Probably f...  date not known
# 1037  The Preaching of Warning. Verso: An Old Man En...         ?c.1785
#
#                                                  medium  \
# id
# 1035  Watercolour, ink, chalk and graphite on paper....
# 1036                                  Graphite on paper
# 1037        Graphite on paper. Verso: graphite on paper
#
#                                creditline    year  acquisitionyear  \
# id
# 1035  Presented by Mrs John Richmond 1922     NaN             1922
# ...

# %%
data.loc[0:3, :] # loc is looking at index where is iloc not
# Out:
# Empty DataFrame
# Columns: [accession_number, artist, artistrole, artistid, title, datetext, medium, creditline, year, acquisitionyear, dimensions, width, height, depth, units, inscription, thumbnailcopyright, thumbnailurl, url]
# Index: []

# %%
data.loc[1035:1037, :]
# Out:
#      accession_number         artist artistrole  artistid  \
# id
# 1035           A00001  Blake, Robert     artist        38
# 1036           A00002  Blake, Robert     artist        38
# 1037           A00003  Blake, Robert     artist        38
#
#                                                   title        datetext  \
# id
# 1035  A Figure Bowing before a Seated Old Man with h...  date not known
# 1036  Two Drawings of Frightened Figures, Probably f...  date not known
# 1037  The Preaching of Warning. Verso: An Old Man En...         ?c.1785
#
#                                                  medium  \
# id
# 1035  Watercolour, ink, chalk and graphite on paper....
# 1036                                  Graphite on paper
# 1037        Graphite on paper. Verso: graphite on paper
#
#                                creditline    year  acquisitionyear  \
# id
# 1035  Presented by Mrs John Richmond 1922     NaN             1922
# ...

# %%
data.iloc[0:3, 0:3]
# Out:
#      accession_number         artist artistrole
# id
# 1035           A00001  Blake, Robert     artist
# 1036           A00002  Blake, Robert     artist
# 1037           A00003  Blake, Robert     artist

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#      id accession_number          artist artistrole  artistid  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                datetext  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %%
data.iloc[0:3, 0:3]
# Out:
#      id accession_number         artist
# 0  1035           A00001  Blake, Robert
# 1  1036           A00002  Blake, Robert
# 2  1037           A00003  Blake, Robert

# %%
data.iloc[[0,5], [0,2]]
# Out:
#      id          artist
# 0  1035   Blake, Robert
# 5  1040  Blake, William

# %%
data.medium
# Out:
# 0    Watercolour, ink, chalk and graphite on paper....
# 1                                    Graphite on paper
# 2          Graphite on paper. Verso: graphite on paper
# 3                                    Graphite on paper
# 4                              Line engraving on paper
# 5                              Line engraving on paper
# 6                              Line engraving on paper
# 7                              Line engraving on paper
# 8                              Line engraving on paper
# 9                              Line engraving on paper
# Name: medium, dtype: object

# %%
type(data.medium)
# Out:
# pandas.core.series.Series

# %%
data.medium.str

# %%
data.medium.str.contains('Graphite')
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: medium, dtype: bool

# %%
data.loc[data.medium.str.contains('graphite|line', case=False, regex=True),['artist','title']]
# Out:
#            artist                                              title
# 0   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1   Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 2   Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 3   Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 4  Blake, William  The Circle of the Lustful: Francesca da Rimini...
# 5  Blake, William      Ciampolo the Barrator Tormented by the Devils
# 6  Blake, William                        The Baffled Devils Fighting
# 7  Blake, William  The Six-Footed Serpent Attacking Agnolo Brunel...
# 8  Blake, William                 The Serpent Attacking Buoso Donati
# 9  Blake, William                 The Pit of Disease: The Falsifiers

# %%
data.year.astype(str).str.contains('182')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: year, dtype: bool

# %%
data.loc[data.dimensions.str.contains('support', na=False) ] ## Nan  cannot support iLoc
# Out:
#      id accession_number         artist artistrole  artistid  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
# 2  1037           A00003  Blake, Robert     artist        38
# 3  1038           A00004  Blake, Robert     artist        38
#
#                                                title        datetext  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
# 2  The Preaching of Warning. Verso: An Old Man En...         ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# 2        Graphite on paper. Verso: graphite on paper
# 3                                  Graphite on paper
#
# ...

# %% [markdown]
# ## bad data

# %%
data = pd.read_csv("artwork_data.csv", low_memory=False)
data.loc[data.title.str.contains('\s$', regex=True)]
# Out:
#           id accession_number                artist artistRole  artistId  \
# 49498   4308           P07466  Hamilton Finlay, Ian     artist      1093
# 50534   2235           P11065         Clarke, Brian     artist       911
# 50535   2236           P11066         Clarke, Brian     artist       911
# 50537   2238           P11068         Clarke, Brian     artist       911
# 53186  21168           P77679     Bourgeois, Louise     artist      2351
# 56283   5826           T00705     Hamilton, Richard     artist      1244
# 67409  88191           T12064          Leach, David     artist      7651
# 67432  88215           T12087        Leach, Bernard     artist      1478
#
#                                                    title dateText  \
# 49498  Port-Distinguishing Letters of Scottish Fishin...     1976
# 50534                                              Boys      1981
# 50535                                         Buildings      1981
# ...

# %%
data.title = data.title.str.strip()

# %%
data.loc[data.title.str.contains('\s$', regex=True)]
# Out:
# Empty DataFrame
# Columns: [id, accession_number, artist, artistRole, artistId, title, dateText, medium, creditLine, year, acquisitionYear, dimensions, width, height, depth, units, inscription, thumbnailCopyright, thumbnailUrl, url]
# Index: []

# %%
data.title.transform(lambda x : x.strip())
# Out:
# 0        A Figure Bowing before a Seated Old Man with h...
# 1        Two Drawings of Frightened Figures, Probably f...
# 2        The Preaching of Warning. Verso: An Old Man En...
# 3           Six Drawings of Figures with Outstretched Arms
# 4        The Circle of the Lustful: Francesca da Rimini...
#                                ...
# 69196                          Larvae (from Tampax Romana)
# 69197                     Living Womb (from Tampax Romana)
# 69198                                        Present Tense
# 69199            Work No. 227: The lights going on and off
# 69200                     Dancing Scene in the West Indies
# Name: title, Length: 69201, dtype: object

# %%
data
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
pd.isna(data.loc[:,'dateText'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 69196    False
# 69197    False
# 69198    False
# 69199    False
# 69200    False
# Name: dateText, Length: 69201, dtype: bool

# %%
from numpy import nan

# %%
data.replace({'dateText':{'date not known':nan}}, inplace=True)

# %%
data
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
data = pd.read_csv("artwork_data.csv", low_memory=False)
data.loc[data.dateText == 'date not known',['dateText']]=nan

# %%
data
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
data.loc[data.year.notnull() & data.year.astype(str).str.contains('[^0-9]')]
# Out:
#            id accession_number            artist artistRole  artistId  \
# 67968   99332           T12629  Roberts, William     artist      1855
# 67980   99346           T12641  Roberts, William     artist      1855
# 67987   99354           T12648  Roberts, William     artist      1855
# 67994   99361           T12655  Roberts, William     artist      1855
# 68002   99370           T12663  Roberts, William     artist      1855
# 68015   99384           T12676  Roberts, William     artist      1855
# 68033   99407           T12694  Roberts, William     artist      1855
# 68042   99426           T12703  Roberts, William     artist      1855
# 68047   99431           T12708  Roberts, William     artist      1855
# 68051   99435           T12712  Roberts, William     artist      1855
# 68056   99440           T12717  Roberts, William     artist      1855
# 68057   99441           T12718  Roberts, William     artist      1855
# ...

# %%
data.loc[data.year.notnull() & data.year.astype(str).str.contains('[^0-9]'), ['year']] = nan # year has to be included or frame will be corrupted

# %%
data.iloc[67968:67969]
# Out:
#           id accession_number            artist artistRole  artistId  \
# 67968  99332           T12629  Roberts, William     artist      1855
#
#                      title dateText             medium  \
# 67968  Families on a beach  no date  Graphite on paper
#
#                                               creditLine     year  \
# 67968  Accepted by HM Government in lieu of inheritan...  no date
#
#        acquisitionYear             dimensions width height  depth units  \
# 67968           2008.0  support: 127 x 178 mm   127    178    NaN    mm
#
#       inscription               thumbnailCopyright  \
# 67968         NaN  © The estate of William Roberts
#
#                                             thumbnailUrl  \
# 67968  http://www.tate.org.uk/art/images/work/T/T12/T...
#
#                                                      url
# 67968  http://www.tate.org.uk/art/artworks/roberts-fa...

# %%
data.fillna(0)

# %%
data.fillna(value={'depth':0}, inplace=True)

# %%
data
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
data.shape
# Out:
# (69201, 20)

# %%
data.dropna()
data.dropna().shape
# Out:
# (3846, 20)

# %%
data.dropna(how="all").shape
# Out:
# (69201, 20)

# %%
data.dropna(thresh=20).shape  # row with 20 na

# %%
data.dropna(subset=['year','acquisitionYear'])
# Out:
#            id accession_number              artist artistRole  artistId  \
# 2        1037           A00003       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# 5        1040           A00006      Blake, William     artist        39
# 6        1041           A00007      Blake, William     artist        39
# 7        1042           A00008      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
data.dropna(subset=['year','acquisitionYear'], how="all").shape
# Out:
# (69198, 20)

# %%
data.dropna(subset=['year','acquisitionYear'], inplace=True)

# %%
data.shape
# Out:
# (63781, 20)

# %%
data= pd.read_csv("artwork_sample.csv")

# %%
data.drop_duplicates()
# Out:
#            id accession_number              artist artistRole  artistId  \
# 2        1037           A00003       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# 5        1040           A00006      Blake, William     artist        39
# 6        1041           A00007      Blake, William     artist        39
# 7        1042           A00008      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
data.drop_duplicates(subset=['artist'])
# Out:
#            id accession_number                             artist  \
# 2        1037           A00003                      Blake, Robert
# 4        1039           A00005                     Blake, William
# 49       1183           A00050                   Richmond, George
# 56       1695           A00057  Burne-Jones, Sir Edward Coley, Bt
# 130      1915           A00131                    Callow, William
# ...       ...              ...                                ...
# 69188  121283           T13857                        Rhodes, Lis
# 69190  117863           T13859               Andrade, Jonathas de
# 69192  123620           T13861                      Sterne, Hedda
# 69194  122958           T13863                 P-Orridge, Genesis
# 69200  127035           T13869                  Brunias, Agostino
#
#           artistRole  artistId  \
# 2             artist        38
# 4             artist        39
# 49     attributed to       447
# 56            artist        68
# ...

# %%
data.drop_duplicates(subset=['artist'], keep='last', inplace=True) #last first, false, delete row duplicate

# %%
data.duplicated()
# Out:
# 2        False
# 4        False
# 5        False
# 6        False
# 7        False
#          ...
# 69196    False
# 69197    False
# 69198    False
# 69199    False
# 69200    False
# Length: 63781, dtype: bool

# %%
data.loc[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, accession_number, artist, artistRole, artistId, title, dateText, medium, creditLine, year, acquisitionYear, dimensions, width, height, depth, units, inscription, thumbnailCopyright, thumbnailUrl, url]
# Index: []

# %%
data.duplicated(subset=['artist','title'], keep=False)

# %%
data.loc[data.duplicated(subset=['artist','title'], keep=False)]
# Out:
#            id accession_number            artist artistRole  artistId  \
# 4        1039           A00005    Blake, William     artist        39
# 5        1040           A00006    Blake, William     artist        39
# 6        1041           A00007    Blake, William     artist        39
# 7        1042           A00008    Blake, William     artist        39
# 8        1043           A00009    Blake, William     artist        39
# ...       ...              ...               ...        ...       ...
# 69169  121194           T13838  Barlow, Phyllida     artist     10908
# 69170  121195           T13839  Barlow, Phyllida     artist     10908
# 69171  121196           T13840  Barlow, Phyllida     artist     10908
# 69172  121197           T13841  Barlow, Phyllida     artist     10908
# 69173  121198           T13842  Barlow, Phyllida     artist     10908
#
#                                                    title  \
# 4      The Circle of the Lustful: Francesca da Rimini...
# ...

# %%
data.loc[data.title.str.contains('The Circle of the Lustful')]
# Out:
#          id accession_number          artist artistRole  artistId  \
# 4      1039           A00005  Blake, William     artist        39
# 57394  1156           T01950  Blake, William     artist        39
#
#                                                    title  \
# 4      The Circle of the Lustful: Francesca da Rimini...
# 57394  The Circle of the Lustful: Francesca da Rimini...
#
#                      dateText                   medium  \
# 4      1826–7, reprinted 1892  Line engraving on paper
# 57394  1826–7, reprinted 1968  Line-engraving on paper
#
#                                               creditLine  year  \
# 4      Purchased with the assistance of a special gra...  1826
# 57394             Presented by Lessing J. Rosenwald 1975  1826
#
#        acquisitionYear           dimensions width height  depth units  \
# 4               1919.0  image: 243 x 335 mm   243    335    0.0    mm
# 57394           1975.0  image: 243 x 335 mm   243    335    0.0    mm
#
# ...
